# %%
import time as t
import os
time = 3600


os.system('cls')

while(time > 0):
    mint = int(time / 60)
    hrs = int((mint/60))
    sec = mint % 60
    print("time left --> ",hrs,":",mint,":",sec)
    time-=1
    t.sleep(1)
    os.system('cls')
# Out:
# time left -->  1 : 60 : 0
# time left -->  0 : 59 : 59
# time left -->  0 : 59 : 59
# time left -->  0 : 59 : 59
# time left -->  0 : 59 : 59
# time left -->  0 : 59 : 59
# time left -->  0 : 59 : 59
# time left -->  0 : 59 : 59
# time left -->  0 : 59 : 59
# time left -->  0 : 59 : 59
# time left -->  0 : 59 : 59
# time left -->  0 : 59 : 59
# time left -->  0 : 59 : 59
# time left -->  0 : 59 : 59
# time left -->  0 : 59 : 59
# time left -->  0 : 59 : 59
# time left -->  0 : 59 : 59
# time left -->  0 : 59 : 59
# time left -->  0 : 59 : 59
# time left -->  0 : 59 : 59
# time left -->  0 : 59 : 59
# time left -->  0 : 59 : 59
# time left -->  0 : 59 : 59
# time left -->  0 : 59 : 59
# time left -->  0 : 59 : 59
# time left -->  0 : 59 : 59
# time left -->  0 : 59 : 59
# time left -->  0 : 59 : 59
# time left -->  0 : 59 : 59
# time left -->  0 : 59 : 59
# time left -->  0 : 59 : 59
# time left -->  0 : 59 : 59
# time left -->  0 : 59 : 59
# time left -->  0 : 59 : 59
# ...
